# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('indonesian_commerce_dataset\customer_orders.csv')
df = df.drop(columns=['created_timestamp', 'accepted_timestamp', 'ready_timestamp', 'collected_timestamp', 'expedition_timestamp', "delivering_timestamp", "delivered_timestamp", 'delivered_timestamp', 'finished_timestamp'])
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 368999 entries, 0 to 368998
# Data columns (total 21 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              368999 non-null  int64
#  1   merchant_id           368999 non-null  int64
#  2   channel_id            368999 non-null  int64
#  3   payment_order_id      368999 non-null  int64
#  4   delivery_order_id     368999 non-null  int64
#  5   order_status          368999 non-null  str
#  6   sales_amount          368999 non-null  float64
#  7   delivery_fee          368999 non-null  float64
#  8   delivery_cost         361794 non-null  float64
#  9   created_hour          368999 non-null  int64
#  10  created_minute        368999 non-null  int64
#  11  created_day           368999 non-null  int64
#  12  created_month         368999 non-null  int64
#  13  created_year          368999 non-null  int64
#  14  collection_time       317507 non-null  float64
# ...

# %%
df2 = pd.read_csv('indonesian_commerce_dataset\delivery_partners.csv')
df2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4824 entries, 0 to 4823
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   driver_id            4824 non-null   int64
#  1   vehicle_type         4824 non-null   str
#  2   driver_partner_type  4824 non-null   str
# dtypes: int64(1), str(2)
# memory usage: 113.2 KB

# %%
df3 = pd.read_csv('indonesian_commerce_dataset\delivery_transactions.csv')
df3.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 378843 entries, 0 to 378842
# Data columns (total 5 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   delivery_id          378843 non-null  int64
#  1   order_delivery_id    378843 non-null  int64
#  2   driver_id            362957 non-null  float64
#  3   delivery_distance_m  378770 non-null  float64
#  4   delivery_status      378843 non-null  str
# dtypes: float64(2), int64(2), str(1)
# memory usage: 14.5 MB

# %%
df4 = pd.read_csv('indonesian_commerce_dataset\distribution_hubs.csv')
df4.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   hub_id            32 non-null     int64
#  1   distribution_hub  32 non-null     str
#  2   city              32 non-null     str
#  3   province          32 non-null     str
# dtypes: int64(1), str(3)
# memory usage: 1.1 KB

# %%
df5 = pd.read_csv('indonesian_commerce_dataset\merchants.csv')
df5.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 951 entries, 0 to 950
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   merchant_id        951 non-null    int64
#  1   hub_id             951 non-null    int64
#  2   merchant_name      951 non-null    str
#  3   business_category  951 non-null    str
#  4   subscription_fee   836 non-null    float64
# dtypes: float64(1), int64(2), str(2)
# memory usage: 37.3 KB

# %%
df6 = pd.read_csv('indonesian_commerce_dataset\payment_transactions.csv')
df6.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 400834 entries, 0 to 400833
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   payment_id        400834 non-null  int64
#  1   order_payment_id  400834 non-null  int64
#  2   payment_amount    400834 non-null  float64
#  3   transaction_fee   400659 non-null  float64
#  4   payment_method    400834 non-null  str
#  5   payment_status    400834 non-null  str
# dtypes: float64(2), int64(2), str(2)
# memory usage: 18.3 MB

# %%
df7 = pd.read_csv('indonesian_commerce_dataset\sales_channels.csv')
df7.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   channel_id        40 non-null     int64
#  1   sales_channel     40 non-null     str
#  2   channel_category  40 non-null     str
# dtypes: int64(1), str(2)
# memory usage: 1.1 KB

# %%
df['sales_amount'].sum()
# Out:
# np.float64(38800730.730000004)

# %%
print(df['sales_amount'].min())
print(df['sales_amount'].max())
# Out:
# 0.0
# 1788306.11

# %%
df.head(10)
# Out:
#    order_id  merchant_id  channel_id  payment_order_id  delivery_order_id  \
# 0  68405119         3512           5          68405119           68405119
# 1  68405123         3512           5          68405123           68405123
# 2  68405206         3512           5          68405206           68405206
# 3  68405465         3401           5          68405465           68405465
# 4  68406064         3401           5          68406064           68406064
# 5  68408108          786           5          68408108           68408108
# 6  68408109         1125           5          68408109           68408109
# 7  68409030         1064          35          68409030           68409030
# 8  68410055         2181          35          68410055           68410055
# 9  68412121         1152           5          68412121           68412121
#
#   order_status  sales_amount  delivery_fee  delivery_cost  created_hour  ...  \
# ...
